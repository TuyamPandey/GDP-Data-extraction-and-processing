# %%
import pandas as pd
import numpy as np

# %%
URL = "https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"
tables =pd.read_html(URL)
df = tables[3]
df.head()
# Out:
#   Country/Territory UN region IMF[1][13]            World Bank[14]             \
#   Country/Territory UN region   Estimate       Year       Estimate       Year
# 0             World         —  105568776       2023      100562011       2022
# 1     United States  Americas   26854599       2023       25462700       2022
# 2             China      Asia   19373586  [n 1]2023       17963171  [n 3]2022
# 3             Japan      Asia    4409738       2023        4231141       2022
# 4           Germany    Europe    4308854       2023        4072192       2022
#
#   United Nations[15]
#             Estimate       Year
# 0           96698005       2021
# 1           23315081       2021
# 2           17734131  [n 1]2021
# 3            4940878       2021
# 4            4259935       2021

# %%
df.columns = range(df.shape[1])
df = df[[0,2]]
df.head()
# Out:
#                0          2
# 0          World  105568776
# 1  United States   26854599
# 2          China   19373586
# 3          Japan    4409738
# 4        Germany    4308854

# %%
df = df.iloc[1:11,:]
df.columns = ['Country','GDP(Million USD)']
df.head()
# Out:
#          Country GDP(Million USD)
# 1  United States         26854599
# 2          China         19373586
# 3          Japan          4409738
# 4        Germany          4308854
# 5          India          3736882

# %%
#change gdp to billion
df['GDP(Million USD)'] = df['GDP(Million USD)'].astype(int)
df['GDP(Million USD)'] = df[['GDP(Million USD)']]/1000
df['GDP(Million USD)'] = np.round(df[['GDP(Million USD)']],2)
df.rename(columns = {'GDP(Million USD)' : 'GDP(Billion USD)'})
# Out:
#            Country  GDP(Billion USD)
# 1    United States          26854.60
# 2            China          19373.59
# 3            Japan           4409.74
# 4          Germany           4308.85
# 5            India           3736.88
# 6   United Kingdom           3158.94
# 7           France           2923.49
# 8            Italy           2169.74
# 9           Canada           2089.67
# 10          Brazil           2081.24

# %%
df.to_csv('./Largest_Economies.csv')

# %% [markdown]
# ![image.png](attachment:24dff705-ce35-408c-8972-faae9907c8c1.png)![image.png](attachment:373c9fad-4bc4-4cc7-a404-3eb000f08bd8.png)
